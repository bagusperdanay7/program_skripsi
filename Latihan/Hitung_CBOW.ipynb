# %%
import numpy as np
import pandas as pd

# Hitung Word2Vec CBOW

# x_w1 = np.array(([(0.907559168072114, 0.0616994677881915, 0.368917460997688)])) # Konteks = senang (indeks 1)
# x_w1 = np.array(([(0.43624820859087, 0.0632383519006329, 0.0935337005044243)])) # Konteks = belanja (indeks 2)
# x_w1 = np.array(([(0.299773043337174, 0.099149005005155, 0.903142883874431)])) # Konteks = online (indeks 3)
# x_w1 = np.array(([(0.574809662801397, 0.765004316054115, 0.186517185435202)])) # Konteks = tidak_pernah (indeks 4)
# x_w1 = np.array(([(0.995827742358186, 0.918757467989847, 0.501377499437710)])) # Konteks = tertipu (indeks 5)
# x_w1 = np.array(([(0.910845525446538, 0.658819588613892, 0.978869470284508)])) # Konteks = penjualnya (indeks 6)
# x_w1 = np.array(([(0.99512772826558, 0.792311415077285, 0.698368771430799)])) # Konteks = jujur (indeks 7)
# x_w1 = np.array(([(0.019197482476776, 0.991782834188414, 0.460193988852446)])) # Konteks = ramah (indeks 8)
# x_w1 = np.array(([(0.539115514131476, 0.465106215040191,	0.084003841279268)])) # Konteks = layanan (indeks 9)
# x_w1 = np.array(([(0.169849026989636, 0.187056340350327, 0.490392145342933)])) # Konteks = pelanggan (indeks 10)
# x_w1 = np.array(([(0.482333265253502, 0.274597618745873, 0.901590240693896)])) # Konteks = sopan (indeks 11)
# x_w1 = np.array(([(0.604426925494087, 0.229511024832985, 0.019781049069185)])) # Konteks = kendala (indeks 12)
# x_w1 = np.array(([(0.614907020286653, 0.507134324373939, 0.024440576843190)])) # Konteks = beda (indeks 13)
# x_w1 = np.array(([(0.324432828928007, 0.546248392898875, 0.806672757730199)])) # Konteks = toko (indeks 14)
# x_w1 = np.array(([(0.965809301181658, 0.914184419277796, 0.845326828195787)])) # Konteks = shop (indeks 15)
# x_w1 = np.array(([(0.332562042150430, 0.369569447315166, 0.382630949778847)])) # Konteks = sebelah (indeks 16)
# x_w1 = np.array(([(0.312428963518740, 0.840634410283428, 0.070161116543523)])) # Konteks = dionline (indeks 17)
# x_w1 = np.array(([(0.802742208619658, 0.363044076526988, 0.294434401784623)])) # Konteks = shope (indeks 18)
# x_w1 = np.array(([(0.469878714237071, 0.972942428342338, 0.900605730828096)])) # Konteks = nyaman (indeks 19)
# x_w1 = np.array(([(0.392492022950568, 0.649887703425706, 0.307280133095774)])) # Konteks = apapun (indeks 20)
# x_w1 = np.array(([(0.768471131919157, 0.340335510481706, 0.236343287732070)])) # Konteks = kesal (indeks 21)
# x_w1 = np.array(([(0.656667253465654, 0.879097181947432, 0.696690153539124)])) # Konteks = serbu (indeks 22)
# x_w1 = np.array(([(0.442857979391712, 0.590116266029078, 0.057451911072873)])) # Konteks = seru (indeks 23)
# x_w1 = np.array(([(0.665957966723586,0.389013471982351,0.285131547148542)])) # Konteks = belum_pernah (indeks 24)
# x_w1 = np.array(([(0.947676588738941,0.449335209459353,0.815569194588044)])) # Konteks = barang (indeks 25)
# x_w1 = np.array(([(0.432957230737899,0.628761450670517,0.396224436050180)])) # Konteks = aplikasi (indeks 26)
# x_w1 = np.array(([(0.657297066967488,0.228612605663952,0.254331808588469)])) # Konteks = bermanfaat (indeks 27)
# x_w1 = np.array(([(0.870457821322887,0.497131219315074,0.768772158855419)])) # Konteks = membantu (indeks 28)
# x_w1 = np.array(([(0.600409624791327,0.887929903192144,0.846033894575827)])) # Konteks = jaman (indeks 29)
# x_w1 = np.array(([(0.880425820415881,0.434787107013862,0.267517093244494)])) # Konteks = mudah (indeks 30)
# x_w1 = np.array(([(0.220759270684597,0.890841383304215,0.570364603972242)])) # Konteks = cepat (indeks 31)
# x_w1 = np.array(([(0.054890284674561,0.966967331586418,0.956160023961521)])) # Konteks = top (indeks 32)
# x_w1 = np.array(([(0.567268627576541,0.344643833474708,0.650821943857037)])) # Konteks = fitur (indeks 33)
# x_w1 = np.array(([(0.298573549729683,0.765469374654227,0.069599134476498)])) # Konteks = harganya (indeks 34)
# x_w1 = np.array(([(0.460889927665945,0.745430624194506,0.855556016035771)])) # Konteks = sukses (indeks 35)
# x_w1 = np.array(([(0.665232823355076,0.843196515336469,0.715562202678074)])) # Konteks = bukalapak (indeks 36)
# x_w1 = np.array(([(0.694857571646255,0.479088985003588,0.825427333981456)])) # Konteks = excelent (indeks 37)
# x_w1 = np.array(([(0.347141493567885,0.580181073927509,0.414376394362199)])) # Konteks = nomor (indeks 38)
# x_w1 = np.array(([(0.928326028627030,0.309819082372590,0.954426576483221)])) # Konteks = wahid (indeks 39)
# x_w1 = np.array(([(0.295896048568338,0.875116521258698,0.349236435241011)])) # Konteks = pelayanan (indeks 40)
x_w1 = np.array(([(0.529210885734485,0.982922689988323,0.797893210651861)])) # Konteks = penjual (indeks 41)
# x_w1 = np.array(([(0.882813009148206,0.915505469988039,0.396699480615077)])) # Konteks = jelek (indeks 42)
# x_w1 = np.array(([(0.098991476777893,0.072863080893008,0.484749520571741)])) # Konteks = bukadompet (indeks 43)
# x_w1 = np.array(([(0.149062940967864,0.941528838862729,0.849144087434268)])) # Konteks = dibekukan (indeks 44)
# x_w1 = np.array(([(0.656344710885715,0.936550976225976,0.238314633406139)])) # Konteks = komplain (indeks 45)
# x_w1 = np.array(([(0.256856187801130,0.421008870371308,0.969368128020710)])) # Konteks = berulang (indeks 46)
# x_w1 = np.array(([(0.947853605462836,0.257456890533150,0.882390116925960)])) # Konteks = bukti (indeks 47)
# x_w1 = np.array(([(0.592936248098670,0.566256513247381,0.392225349026821)])) # Konteks = transaksi (indeks 48)
# x_w1 = np.array(([(0.084283649970093,0.326257080568315,0.983453995343077)])) # Konteks = valid (indeks 49)
# x_w1 = np.array(([(0.060701857245324,0.212594659784071,0.033141383689913)])) # Konteks = hasil (indeks 50)
# x_w1 = np.array(([(0.754969083030328,0.327526589529068,0.521990076917653)])) # Konteks = penjualan (indeks 51)
# x_w1 = np.array(([(0.182750671536809,0.010999510174738,0.600857518544018)])) # Konteks = ditahan (indeks 52)
# x_w1 = np.array(([(0.861316403096618,0.067396860500267,0.600879923914831)])) # Konteks = mohon (indeks 53)
# x_w1 = np.array(([(0.024588120427916,0.363116322092069,0.990129611327477)])) # Konteks = aktifkan (indeks 54)
# x_w1 = np.array(([(0.220483489522069,0.906520337077481,0.539325995461551)])) # Konteks = bagus (indeks 55)
# x_w1 = np.array(([(0.790551860053109,0.400462955368231,0.425564007842312)])) # Konteks = sesuai (indeks 56)
# x_w1 = np.array(([(0.475664710661860,0.973930635134620,0.920578570402922)])) # Konteks = pengiriman (indeks 57)
# x_w1 = np.array(([(0.223689765083299,0.886988256707017,0.316494546319695)])) # Konteks = tingkatkan (indeks 58)
# x_w1 = np.array(([(0.721433340126869,0.478152731257094,0.185868847665281)])) # Konteks = admin (indeks 59)
# x_w1 = np.array(([(0.465008116673465,0.038423009756836,0.223612341762661)])) # Konteks = biar (indeks 60)
# x_w1 = np.array(([(0.949499550287111,0.232316236351282,0.925122169810558)])) # Konteks = semangat (indeks 61)
# x_w1 = np.array(([(0.332812830092575,0.387121769351183,0.698398189679475)])) # Konteks = hahaha (indeks 62)
# x_w1 = np.array(([(0.498648748517189,0.110654906813384,0.628425061472316)])) # Konteks = <LAYANAN> (indeks 63)
# x_w1 = np.array(([(0.686261926866143,0.694464168731286,0.885922367685716)])) # Konteks = <FITUR> (indeks 64)
# x_w1 = np.array(([(0.400512673725666,0.221808375311402,0.899782088508179)])) # Konteks = <KEBERMANFAATAN> (indeks 65)
# x_w1 = np.array(([(0.381282707845289,0.630834228262963,0.575704255725956)])) # Konteks = <BISNIS> (indeks 66)
# x_w1 = np.array(([(0.439599339617951,0.633734857250442,0.403411499243141)])) # Konteks = <NON ASPEK> (indeks 67)
# x_w1 = np.array(([(0.793178289583349,0.983531788083570,0.443130487172576)])) # Konteks = <UNKNOWN> (indeks 68)



# Konteks = pelayanan, target = jelek
# x_w1 = np.array(([(0.295896048568338, 0.875116521258698, 0.349236435241011)]))


print('Matriks X * W1 = \n', x_w1, '\n')

wo = np.array(([0.888563979365201, 0.218313935186904, 0.580796934329850, 0.681545213455374, 0.927491847520756, 0.057652099980229, 0.964854706839704, 0.000570784865009, 0.781632570359999, 0.964367105429220, 0.098471988604675, 0.652514637920216, 0.610215722100892, 0.964043033160407, 0.535003013956565, 0.855455728652069, 0.716816837940844, 0.972308253104550, 0.117566238323095, 0.017978514903416, 0.114566126299784, 0.237463238883085, 0.297068781572555, 0.667025402287037, 0.558042551983460, 0.818564426814474, 0.140570123113170, 0.389408885580430, 0.541926876918667, 0.637492361665503, 0.120435535599047, 0.761205275353343, 0.072919409315591, 0.166073093004713, 0.316652429446665, 0.083219425917841, 0.931314438520837, 0.294830136424495, 0.291981827717498, 0.492446418745864, 0.307499481429108, 0.747951627690622, 0.414038647108478, 0.505714070395031, 0.843100793893863, 0.941210144199850, 0.632507187534394, 0.178042901444692, 0.782602892206363, 0.989205176606322, 0.967793286825441, 0.784785049188179, 0.797204574420512, 0.517966112648770, 0.171741490804255, 0.913320487158477, 0.922966041886655, 0.733539577861614, 0.656804549035976, 0.420937755432511, 0.761828746136406, 0.228489252387893, 0.390532826272719, 0.402222605074492, 0.961791113105603, 0.049410160338014, 0.453077906047781, 0.962461828896374],
[0.974344793589976,	0.751722890380824,	0.763469076083616,	0.304551547996851,	0.266194052059271,	0.544718234770658,	0.484716209030235,	0.715274222244976,	0.654541486157574,	0.636167560264755,	0.505765666445419,	0.318309637470674,	0.073483134048993,	0.337399718844010,	0.311282191443645,	0.087435107850281,	0.507966776354144,	0.461180240474609,	0.401530772902720,	0.728337941748544,	0.268489813158173,	0.889556241614190,	0.160452713841916,	0.798622281362812,	0.316890232224549,	0.051735862984310,	0.536946347309393,	0.461798503497999,	0.067020724134713,	0.432349817559332,	0.280191630821428,	0.239835813820470,	0.800880854805450,	0.270725850360651,	0.466526422802128,	0.191460058627431,	0.335043914238249,	0.721889536074550,	0.441002583816223,	0.130566990213852,	0.367033784265990,	0.897241650851948,	0.795304772873041,	0.078080145255067,	0.022585575514360,	0.603599614703498,	0.527312552458811,	0.848439522477953,	0.530950277591858,	0.659536477269735,	0.517126337014028,	0.174220711616174,	0.426183106005842,	0.498545071305308,	0.205441503854195,	0.253002970797249,	0.438193363626917,	0.593906752915362,	0.338847260716643,	0.171643679728545,	0.025088349305311,	0.008594709473533,	0.499375376368382,	0.744859738473849,	0.373017199247224,	0.957838871990445,	0.045550500039313,	0.822064789041146],
[0.529292105839121,	0.770768907365604,	0.716704240994275,	0.333990174273797,	0.328071866660900,	0.615717807054809,	0.833257819661222,	0.662527405812146,	0.127911795206998,	0.784794397354449,	0.166702010471746,	0.796402444086605,	0.522419049163537,	0.257642549222496,	0.458313554899391,	0.446523580738361,	0.031161283880481,	0.473591137687783,	0.320492824553229,	0.291320400350903,	0.567305641514417,	0.802240668029179,	0.272989987178495,	0.352542530479943,	0.867072540237627,	0.756553419099302,	0.816357786793103,	0.057480425733755,	0.573016702727897,	0.266712355406567,	0.494384140033599,	0.661991860064933,	0.422266789695167,	0.159985522405666,	0.960561030973873,	0.256921243921245,	0.830023862323862,	0.556622239685314,	0.261992023787515,	0.860443421991516,	0.935752898941041,	0.282287777370737,	0.930976656130412,	0.834003869129923,	0.768039567712267,	0.004591816217233,	0.388385660861922,	0.268289631916889,	0.007046112811189,	0.590923570806926,	0.253716820005544,	0.207409834878488,	0.878748391719332,	0.434988662136596,	0.685927767070524,	0.368389630523654,	0.642725453367186,	0.951115181431175,	0.520645685942289,	0.826746356219077,	0.866585417032627,	0.659977734955393,	0.588991718438790,	0.468734347180679,	0.443635953096195,	0.922646908133139,	0.223169234942836,	0.006727575370675]))

print('Wo = \n', wo,'\n')

# perkalian matriksnya

def dot_produk_matriks(matriks_1, matriks_2):
    hasil_kali_matriks = np.dot(matriks_1, matriks_2)
    return hasil_kali_matriks

hasil = dot_produk_matriks(x_w1, wo)

print("hasil: \n", hasil, '\n')
print("Dimensi Hasil Matriks", hasil.shape)
# Out:
# Matriks X * W1 =
#  [[0.52921089 0.98292269 0.79789321]]
#
# Wo =
#  [[8.88563979e-01 2.18313935e-01 5.80796934e-01 6.81545213e-01
#   9.27491848e-01 5.76521000e-02 9.64854707e-01 5.70784865e-04
#   7.81632570e-01 9.64367105e-01 9.84719886e-02 6.52514638e-01
#   6.10215722e-01 9.64043033e-01 5.35003014e-01 8.55455729e-01
#   7.16816838e-01 9.72308253e-01 1.17566238e-01 1.79785149e-02
#   1.14566126e-01 2.37463239e-01 2.97068782e-01 6.67025402e-01
#   5.58042552e-01 8.18564427e-01 1.40570123e-01 3.89408886e-01
#   5.41926877e-01 6.37492362e-01 1.20435536e-01 7.61205275e-01
#   7.29194093e-02 1.66073093e-01 3.16652429e-01 8.32194259e-02
#   9.31314439e-01 2.94830136e-01 2.91981828e-01 4.92446419e-01
#   3.07499481e-01 7.47951628e-01 4.14038647e-01 5.05714070e-01
#   8.43100794e-01 9.41210144e-01 6.32507188e-01 1.78042901e-01
#   7.82602892e-01 9.89205177e-01 9.67793287e-01 7.84785049e-01
#   7.97204574e-01 5.17966113e-01 1.71741491e-01 9.13320487e-01
# ...

# %% [markdown]
# Softmax

# %%
eksponensialkan = np.exp(hasil)
print('Eksponensial : \n', eksponensialkan, '\n')

print(f"Sum Eksponensial: {np.sum(eksponensialkan)} ", '\n')

probabilitas_softmax = eksponensialkan / np.sum(eksponensialkan)
print('Probabilitas Softmax \n', probabilitas_softmax, '\n')

# Maka jika probabilitas masing-masing dijumlahkan hasilnya akan bernilai satu
probabilitas_softmax.sum()

print(probabilitas_softmax.shape)

df_Word2Vec = pd.DataFrame(data=hasil)
df_Word2Vec
# Out:
# Eksponensial :
#  [[6.36148546 4.34667365 5.10208146 2.52570509 2.75730367 2.87830935
#   5.21688735 3.42803581 3.1869747  5.82313759 1.97832673 3.64601838
#   2.25239851 2.85020564 2.59810159 2.44718056 2.46823352 3.84101167
#   2.03930709 2.6061053  2.17533721 5.15586823 1.70359633 4.13411119
#   3.66428082 2.96742447 3.50270078 2.02557759 2.24762911 2.65154455
#   2.08258156 3.21162485 3.19861375 1.61872958 4.02514302 1.54840718
#   4.4125573  3.705114   2.21894768 2.93142082 3.5613112  4.49505913
#   5.71821572 2.74511279 2.94819037 2.98934467 3.19928531 3.13377759
#   2.5642527  5.17203083 3.39702783 2.12135107 4.67365658 3.03805974
#   2.31663961 2.78976424 4.18698185 5.64544993 2.99237814 2.86088957
#   3.0626195  1.92698901 3.21386449 3.7396801  3.41990068 5.49480807
#   1.58821636 3.75368978]]
#
# Sum Eksponensial: 224.28323997266818
#
# Probabilitas Softmax
#  [[0.02836362 0.01938029 0.02274838 0.01126123 0.01229385 0.01283337
# ...

# %%
df_Word2Vec.to_excel("hitung_word2vec_dr_program.xlsx")
